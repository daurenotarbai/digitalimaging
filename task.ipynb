# %%
from skimage.io import imread, imshow, imsave
img = imread('1.jpg')
imshow(img)

# %%
img.shape
# Out:
# (1104, 1771, 3)

# %%
startPointR = int((img.shape[0] - (img.shape[0]-20)))
endPointR = startPointR + 100
startPointC = int((img.shape[1] - (img.shape[1]-20)))
endPointC = startPointC + 100
img[startPointR:endPointR, startPointC:endPointC] = [50,205,50]

# %%
startPointR = int((img.shape[0] - 120))
endPointR = startPointR + 100
startPointC = int((img.shape[1] - 120))
endPointC = startPointC + 100
img[startPointR:endPointR, startPointC:endPointC] = [50,205,50]

# %%
startPointR = int((img.shape[0] - 120))
endPointR = startPointR + 100
startPointC = int((img.shape[1] - (img.shape[1]-20)))
endPointC = startPointC + 100
img[startPointR:endPointR, startPointC:endPointC] = [50,205,50]

# %%
startPointR = int((img.shape[0] - (img.shape[0]-20)))
endPointR = startPointR + 100
startPointC = int((img.shape[1] - 120))
endPointC = startPointC + 100
img[startPointR:endPointR, startPointC:endPointC] = [50,205,50]
imshow(img)
