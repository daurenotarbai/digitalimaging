# %%
from skimage.io import imread, imshow, imsave
img = imread('bg-1.jpg')
imshow(img)

# %%
img.shape
# Out:
# (1080, 1920, 3)

# %%
startPointR = int((img.shape[0] - 7) / 2)
endPointR = startPointR + 7
startPointC = int((img.shape[1] - 15) / 2)
endPointC = startPointC + 15
img[startPointR:endPointR, startPointC:endPointC] = [255, 192, 203]
imshow(img)
